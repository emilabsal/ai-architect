# %% [markdown]
# 1. **Выгрузка датасета из своей репы**

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Anglu4anun/attestation-1/main/dataset_tk.csv")

# %%
df.head(n= 30)
# Out:
#              Unnamed: 0  Punjab  Haryana  Rajasthan  Delhi     UP  \
# 0   02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9
# 1   03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8
# 2   04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7
# 3   05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0
# 4   06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8
# 5   07/01/2019 00:00:00   118.0    132.1      241.9   71.1  294.2
# 6   08/01/2019 00:00:00   107.5    121.4      237.2   69.0  289.4
# 7   09/01/2019 00:00:00   132.5    148.2      197.0   89.2  258.6
# 8   10/01/2019 00:00:00   131.5    157.0      199.9   92.8  284.2
# 9   11/01/2019 00:00:00   130.3    145.3      187.7   79.5  281.4
# 10  12/01/2019 00:00:00   137.9    151.9      189.9   92.6  298.6
# 11  13/01/2019 00:00:00   135.8    141.4      186.9   89.4  310.0
# 12  14/01/2019 00:00:00   139.3    143.8      195.2   82.2  319.5
# ...

# %% [markdown]
# 2. **Анализ данных из датасета по различным типам**

# %%
import numpy as np

# %%
print("Количество уникальных значений:")
print(df.nunique())
# Out:
# Количество уникальных значений:
# Unnamed: 0           498
# Punjab               394
# Haryana              388
# Rajasthan            379
# Delhi                337
# UP                   444
# Uttarakhand          203
# HP                   138
# J&K                  172
# Chandigarh            48
# Chhattisgarh         272
# Gujarat              403
# MP                   407
# Maharashtra          422
# Goa                   69
# DNH                   82
# Andhra Pradesh       318
# Telangana            387
# Karnataka            393
# Kerala               231
# Tamil Nadu           411
# Pondy                 56
# Bihar                297
# Jharkhand             94
# Odisha               283
# West Bengal          365
# Sikkim                22
# Arunachal Pradesh     17
# Assam                168
# Manipur               16
# Meghalaya             36
# Mizoram               11
# Nagaland              12
# Tripura               38
# dtype: int64

# %%
print("Минимальное значение:")
print(df.min())
# Out:
# Минимальное значение:
# Unnamed: 0           01/01/2020 00:00:00
# Punjab                              56.1
# Haryana                             64.8
# Rajasthan                          105.8
# Delhi                               41.8
# UP                                 186.8
# Uttarakhand                         16.8
# HP                                  11.8
# J&K                                 17.8
# Chandigarh                           2.2
# Chhattisgarh                        37.2
# Gujarat                            192.3
# MP                                 131.8
# Maharashtra                        305.6
# Goa                                  6.2
# DNH                                  1.3
# Andhra Pradesh                     130.6
# Telangana                          130.5
# Karnataka                          121.0
# Kerala                              55.0
# Tamil Nadu                         195.7
# Pondy                                4.0
# ...

# %%
print("Максимальное значение:")
print(df.max())
# Out:
# Максимальное значение:
# Unnamed: 0           31/12/2019 00:00:00
# Punjab                             300.0
# Haryana                            237.2
# Rajasthan                          278.0
# Delhi                              147.1
# UP                                 471.8
# Uttarakhand                         53.2
# HP                                  34.0
# J&K                                 54.2
# Chandigarh                           7.4
# Chhattisgarh                       111.6
# Gujarat                            400.8
# MP                                 272.3
# Maharashtra                        522.1
# Goa                                 14.0
# DNH                                 19.5
# Andhra Pradesh                     205.1
# Telangana                          256.2
# Karnataka                          273.3
# Kerala                              89.4
# Tamil Nadu                         365.4
# Pondy                                9.7
# ...

# %%
#df.describe ('Статистика всех числовых столбцов')
df.describe ()
# Out:
#            Punjab     Haryana   Rajasthan       Delhi          UP  \
# count  503.000000  503.000000  503.000000  503.000000  503.000000
# mean   141.145527  138.333598  218.443340   83.380716  314.036382
# std     56.977361   38.106593   27.421615   25.915357   66.516960
# min     56.100000   64.800000  105.800000   41.800000  186.800000
# 25%    104.000000  114.800000  205.800000   63.500000  263.650000
# 50%    118.300000  126.800000  222.900000   72.700000  290.000000
# 75%    162.500000  158.100000  237.600000  105.800000  370.550000
# max    300.000000  237.200000  278.000000  147.100000  471.800000
#
#        Uttarakhand          HP         J&K  Chandigarh  Chhattisgarh  ...  \
# count   503.000000  503.000000  503.000000  503.000000    503.000000  ...
# mean     36.157058   26.568191   44.264016    4.141551     83.877137  ...
# std       6.705108    4.807040    4.769391    1.143422     10.130427  ...
# min      16.800000   11.800000   17.800000    2.200000     37.200000  ...
# ...

# %%
#Статистика для каждого столбца
df.describe (include='all')
# Out:
#                  Unnamed: 0      Punjab     Haryana   Rajasthan       Delhi  \
# count                   503  503.000000  503.000000  503.000000  503.000000
# unique                  498         NaN         NaN         NaN         NaN
# top     12/07/2019 00:00:00         NaN         NaN         NaN         NaN
# freq                      2         NaN         NaN         NaN         NaN
# mean                    NaN  141.145527  138.333598  218.443340   83.380716
# std                     NaN   56.977361   38.106593   27.421615   25.915357
# min                     NaN   56.100000   64.800000  105.800000   41.800000
# 25%                     NaN  104.000000  114.800000  205.800000   63.500000
# 50%                     NaN  118.300000  126.800000  222.900000   72.700000
# 75%                     NaN  162.500000  158.100000  237.600000  105.800000
# max                     NaN  300.000000  237.200000  278.000000  147.100000
#
# ...

# %%
#Статистика для одного столбца
df['Delhi']. describe ()
# Out:
# count    503.000000
# mean      83.380716
# std       25.915357
# min       41.800000
# 25%       63.500000
# 50%       72.700000
# 75%      105.800000
# max      147.100000
# Name: Delhi, dtype: float64

# %%
#Статистика для нескольких столбцов
df[['Delhi', 'Arunachal Pradesh', 'Punjab', 'Haryana', 'Rajasthan', 'Odisha', 'West Bengal']]. describe ()
# Out:
#             Delhi  Arunachal Pradesh      Punjab     Haryana   Rajasthan  \
# count  503.000000         503.000000  503.000000  503.000000  503.000000
# mean    83.380716           2.109145  141.145527  138.333598  218.443340
# std     25.915357           0.231132   56.977361   38.106593   27.421615
# min     41.800000           1.100000   56.100000   64.800000  105.800000
# 25%     63.500000           2.000000  104.000000  114.800000  205.800000
# 50%     72.700000           2.200000  118.300000  126.800000  222.900000
# 75%    105.800000           2.200000  162.500000  158.100000  237.600000
# max    147.100000           2.700000  300.000000  237.200000  278.000000
#
#            Odisha  West Bengal
# count  503.000000   503.000000
# mean    80.464612   138.708151
# std     10.905131    27.849180
# min     51.100000    51.500000
# 25%     71.650000   114.650000
# 50%     79.800000   131.200000
# 75%     88.400000   164.750000
# max    113.000000   198.500000
# ...

# %% [markdown]
# 3. **Построение диаграмм для визуализации результатов**

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# Гистограмма
plt.hist(df[['Delhi', 'Arunachal Pradesh', 'Punjab', 'Haryana', 'Rajasthan', 'Odisha', 'West Bengal']])
plt.xlabel('')
plt.ylabel('')
plt.title('Энергопотребление')
plt.show()

# %%
def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
  if sort_ascending:
    df = df.sort_values(y).reset_index(drop=True)
  _, ax = plt.subplots(figsize=figsize)
  df[y].plot(kind='line')
  plt.title(y)
  ax.spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz.MplChart.from_current_mpl_state()
chart = value_plot(df_5975377457591650698, *[['Delhi', 'Arunachal Pradesh', 'Arunachal Pradesh', 'Punjab', 'Punjab', 'Haryana','Haryana', 'Rajasthan']], **{})
chart
# Out:
# <img src="...

# %%
def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
  plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
  for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
    ax = plt.subplot(1, len(colname_pairs), plot_i)
    ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
    plt.xlabel(x_colname)
    plt.ylabel(y_colname)
    ax.spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz.MplChart.from_current_mpl_state()

chart = scatter_plots(df_5975377457591650698, *[[['Delhi', 'Arunachal Pradesh'], ['Arunachal Pradesh', 'Punjab'], ['Punjab', 'Haryana'], ['Haryana', 'Rajasthan']]], **{})
chart
# Out:
# <img src="...

# %% [markdown]
# 4. **2 интересных наблюдения на основании анализа данных**

# %% [markdown]
# 1. В  штате Punjab зафиксировано самое высокое значение напряжения, причина этому, что в данном штате самая развитая в Индии инфраструктура (это подтвержденная информация)
# 2. Наблюдается увеличение энергопотребления во всех городах с января по апрель 2019 года. Это может быть связано с увеличением потребления энергии в холодные месяцы, когда требуется больше энергии для отопления.
